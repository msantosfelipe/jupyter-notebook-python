# %% [markdown]
# <center> Seaborn</center>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.get_dataset_names()
# Out:
# /home/felipe/anaconda3/lib/python3.7/site-packages/seaborn/utils.py:376: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 376 of the file /home/felipe/anaconda3/lib/python3.7/site-packages/seaborn/utils.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   gh_list = BeautifulSoup(http)
# ['anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'iris',
#  'mpg',
#  'planets',
#  'tips',
#  'titanic']

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
# total_bill    244 non-null float64
# tip           244 non-null float64
# sex           244 non-null category
# smoker        244 non-null category
# day           244 non-null category
# time          244 non-null category
# size          244 non-null int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.2 KB

# %%
sns.barplot( x='day', y='total_bill', data=tips)

# %%
sns.barplot(x='tip', y='day', data=tips, orient='h')

# %%
sns.barplot(x='day', y='tip', data=tips, hue='sex')

# %%
# grafico de contagem
sns.countplot(x='sex', data=tips)

# %%
#diagrama de caixa

sns.boxplot(x='sex', y='total_bill', data=tips)

# %%
plt.figure(figsize=[17,17])
sns.boxplot(x='day', y='total_bill', hue='time', data=tips)

# %%
sns.violinplot(x='day', y='total_bill', hue='sex', data=tips, split=False)

# %%
sns.violinplot(x='day', y='total_bill', hue='sex', data=tips, split=True)

# %%
# diversificando distribuicao


sns.distplot(tips['total_bill'])

# %%
sns.distplot(tips['total_bill'], bins=50) # numero de intervalos no histograma

# %%
sns.distplot(tips['tip'], kde=False, rug=True)

# %%
sns.kdeplot(tips['tip'])

# %%
sns.lmplot(x='total_bill', y='tip', data=tips)
plt.xlabel('Total da conta')
plt.ylabel('Gorjeta')
# Out:
# Text(10.049999999999997, 0.5, 'Gorjeta')

# %%
# plotando com polimonio de grau 3
sns.lmplot(x='total_bill', y='tip', data=tips, order=3)
plt.text(10,0, 'equacao')
# Out:
# Text(10, 0, 'equacao')

# %%
sns.lmplot(x='total_bill', y='tip', data=tips, fit_reg=False) # plotando sem a linha de tendencia

# %%
# enriquecendo o grafico

sns.jointplot(x='total_bill', y='tip', data=tips)

# %%
sns.jointplot(x='total_bill', y='tip', data=tips, kind='hex')

# %%
sns.pairplot(tips)

# %%
iris = sns.load_dataset('iris')

# %%
sns.pairplot(iris)

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
#calculando correlacoes no conjunto de dados

irisCorr = iris.corr()

# %%
irisCorr
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
sns.heatmap(irisCorr, annot=True, cmap='coolwarm')

# %%
irisCov = iris.cov()

sns.heatmap(irisCov, annot=True, cmap='coolwarm')

# %%
irisCov
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      0.685694    -0.042434      1.274315     0.516271
# sepal_width      -0.042434     0.189979     -0.329656    -0.121639
# petal_length      1.274315    -0.329656      3.116278     1.295609
# petal_width       0.516271    -0.121639      1.295609     0.581006

# %%
tourist = pd.read_csv('touristData.csv')

# %%
sns.dogplot()

# %%
# grafico com clusters

g = sns.PairGrid(iris)
g.map_diag(sns.kdeplot)
g.map_offdiag(sns.kdeplot)
